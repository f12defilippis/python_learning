# %%
import library as util
import strategy_library as sl

SMA_SLOW = 200
SMA_FAST = 10

COSTS = 0
INSTRUMENT = 1
OPERATION_MONEY = 10000
DIRECTION = "long"
ORDER_TYPE = "market"

str_sma_slow = 'sma'+str(SMA_SLOW)
str_sma_fast = 'sma'+str(SMA_FAST)

data = util.load_data('TIT.MI', '2000-01-01', '2021-01-01')

data[str_sma_slow] = util.sma(data['close'], SMA_SLOW)
data[str_sma_fast] = util.sma(data['close'], SMA_FAST)
data = data.apply(lambda x: round(x, 2))


enter_rules = util.crossover(data['close'],data[str_sma_slow])
exit_rules = util.crossunder(data['close'],data[str_sma_slow])
enter_level = data.open


trading_system = sl.apply_trading_system(data,DIRECTION,ORDER_TYPE,enter_level,enter_rules,exit_rules)



sl.print_performance_report(trading_system, True)

trading_system.to_csv('tradingsystem.csv')
# Out:
# Profitto:                          113874.19
# Numero Operazioni chiuse:          28
# Media dei profitti:                4066.94
# Max Draw Down Open:                -33391.31
# Max Draw Down Closed:              -2523.99
# Avg Draw Down Open:                -5983.43
# Avg Draw Down Closed:              -1185.55
# Draw Down Open Ratio:              0.18
# Draw Down Closed Ratio:            0.47
# Perdita media:                     -478.22
# Perdita massima:                   -1506.02
# Data Perdita massima:              2001-07-19 00:00:00
# Guadagno medio:                    8612.09
# Guadagno massimo:                  68260.87
# Data Guadagno massimo:             2006-05-23 00:00:00
# Profit Factor:                     18.01
# % Vincite:                         50.0
# Reward Risk Ratio:                 18.01
# Max Ritardo Tra Massimi:           1255
# Avg Ritardo Tra Massimi:           34.16
# Operazioni Aperte:                 1
# Date
# 2006-05-23    68260.87
# 2006-08-08     -209.42
# 2006-08-29       31.28
# 2008-01-23    10811.65
# 2008-04-11     -354.19
# 2008-07-22      703.91
# 2008-07-24     -238.60
# 2008-09-04     -674.90
# 2011-06-24    17304.55
# 2011-11-25     1160.30
# 2012-11-02     5526.17
# 2013-09-16    -1003.80
# 2015-08-03     7462.82
# 2015-11-05     -164.05
# 2016-04-15     -244.58
# 2018-02-05     4860.35
# 2018-02-07     -171.68
# 2018-04-23      229.70
# 2018-11-13     1065.46
# 2019-03-25     -188.39
# 2019-05-13     -244.91
# 2020-03-16     2701.94
# 2020-03-18      317.80
# 2020-03-27      -79.53
# 2020-04-01     -597.03
# Name: operations, dtype: float64
