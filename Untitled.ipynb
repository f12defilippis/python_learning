# %%
import library as util
import strategy_library as sl

SMA_SLOW = 50
SMA_FAST = 20

COSTS = 0
INSTRUMENT = 1
OPERATION_MONEY = 10000
DIRECTION = "long"
ORDER_TYPE = "market"

str_sma_slow = 'sma'+str(SMA_SLOW)
str_sma_fast = 'sma'+str(SMA_FAST)

data = util.load_data('ACN', '2000-01-01', '2021-01-01')

data[str_sma_slow] = util.sma(data['close'], SMA_SLOW)
data[str_sma_fast] = util.sma(data['close'], SMA_FAST)
data = data.apply(lambda x: round(x, 2))


enter_rules = util.crossover(data[str_sma_fast], data[str_sma_slow])
exit_rules = util.crossunder(data[str_sma_fast], data[str_sma_slow])
enter_level = data.open


trading_system = sl.apply_trading_system(data,DIRECTION,ORDER_TYPE,enter_level,enter_rules,exit_rules)
sl.print_performance_report(trading_system, True)

trading_system.to_csv('tradingsystem.csv')
# Out:
# Profitto:                          15578.54
# Numero Operazioni chiuse:          43
# Media dei profitti:                362.29
# Max Draw Down Open:                -5752.28
# Max Draw Down Closed:              -1804.67
# Avg Draw Down Open:                -1631.19
# Avg Draw Down Closed:              -1072.57
# Draw Down Open Ratio:              0.28
# Draw Down Closed Ratio:            0.59
# Perdita media:                     -593.82
# Perdita massima:                   -1616.05
# Data Perdita massima:              2002-09-20 00:00:00
# Guadagno medio:                    1193.7
# Guadagno massimo:                  5263.16
# Data Guadagno massimo:             2004-01-27 00:00:00
# Profit Factor:                     2.31
# % Vincite:                         53.49
# Reward Risk Ratio:                 2.01
# Max Ritardo Tra Massimi:           753
# Avg Ritardo Tra Massimi:           52.68
# Operazioni Aperte:                 1
# Date
# 2011-03-21      56.00
# 2011-06-20    -109.29
# 2011-08-15    -925.90
# 2011-12-06     451.56
# 2012-05-10     130.05
# 2012-11-16    1527.56
# 2013-06-28     260.28
# 2013-10-17    -493.88
# 2014-04-03     361.93
# 2014-07-18    -246.73
# 2014-10-07    -408.56
# 2015-02-17     591.46
# 2015-02-20      64.43
# 2015-09-01     393.11
# 2015-12-28     145.63
# 2016-07-05     716.46
# 2016-09-13    -411.26
# 2017-01-11    -490.99
# 2017-04-12    -602.04
# 2018-03-26    2678.31
# 2018-08-14     339.37
# 2018-10-18    -752.77
# 2019-06-03    1499.84
# 2019-10-01     217.54
# 2020-02-27    -929.40
# Name: operations, dtype: float64
